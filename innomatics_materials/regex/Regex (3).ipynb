# %% [markdown]
# # Regex

# %% [markdown]
# ## Regular Expression
#
# A regular expression, often called a pattern, is **an expression used to specify a set of strings** required for a particular purpose.
#
# - A simple way to specify a finite set of strings is to list its elements or members. <br>For example `{Doc1,1,Doc2,2,Doc3,3}`.
#
#
# `{Doc1,Doc2,Doc3}` can be specified by the pattern `Doc(1|2|3)`. <br>We say that this pattern matches each of the two strings. [Lets check?](https://regex101.com/)
# [Regexr](https://regexr.com/)
#
# > In most formalisms, if there exists at least one regular expression that matches a particular set then there exists an infinite number of other regular expressions that also match it, i.e. **the specification is not unique**.<br>
# For example, the string set `{Doc1,Doc2,Doc3}` can also be specified by the pattern `Doc\d`.

# %%
#!pip install regex

# %%
import re

# %% [markdown]
# ## Uses of Regular Expressions
#
# **Some important usages of regular expressions are:**
#
# - Check if an input honors a given pattern; for example, we can check whether a value entered in a HTML formulary is a valid e-mail address
# > `Maniteja123@gmail.com`
#
# - Look for a pattern appearance in a piece of text; for example, check if either the word "color" or the word "colour" appears in a document with just **one scan**
# > `I like Red color and i am wearing a Red colour shirt`
#
# - Extract specific portions of a text; for example, extract the postal code of an address
# > `Mr John Smith. 132, My Street, Kingston, New York 12401.`
#
# - Replace portions of text; for example, change the appearance of "color" with "colour"
# > `I like Red colour and i am wearing a Red colour shirt`
#
# - Split a larger text into smaller pieces, for example, splitting a text by any appearance of the dot, comma, or newline characters
# > `myself person1,you are person2`

# %% [markdown]
# # Meta Characters
#
# - All meta characters. `^ $ * + ? { } \ | ( ) `
#
#   1. `.` any character (except new line character)
#   2. `^` startswith `^word`
#   3. `$` endswith `word$`
#   4. `*` zero or more occurrences
#   5. `+` one or more occurrences
#   6. `{}` exactly specified no of occurrences "M{2}"
#   7. `[]` A set of characters "[a-c]"
#   8. `\` Signals a special sequence (can also be used to escape special characters) "\d"
#   9. `|` Either or "apple|iphone"
#   10. `()` Capture and group

# %%
a = "hat hit hot hut h6t h%t h t"
print(re.findall(r"h.t",a))
print(re.findall(r"h\wt",a))  # a-z-0-9-_
print(re.findall(r"h\dt",a))
print(re.findall(r"h\Wt",a)) #^a-z-0-9-_
# Out:
# ['hat', 'hit', 'hot', 'hut', 'h6t', 'h%t', 'h t']
# ['hat', 'hit', 'hot', 'hut', 'h6t']
# ['h6t']
# ['h%t', 'h t']

# %%
b= "hello world"
print(re.findall(r"^z",b))
print(re.findall(r"^h",b))
print(re.findall(r"^@",b))

# \A
print(re.findall(r"\A@",b))
# Out:
# []
# ['h']
# []
# []

# %%
b= """hello world 
     \nhello world 
     \nhello world"""

print(re.findall(r"\Ahello",b,re.MULTILINE))
print(re.findall(r"^hello",b,re.MULTILINE))
print()
# Out:
# ['hello']
# ['hello', 'hello', 'hello']
# hello world
# hello world
# hello world

# %%
c = "hello world"

print(re.findall(r"world$",b))
# Out:
# ['world']

# %%
b= """hello world
      \nhello world
      \nhello world"""

print(re.findall(r"world\Z",b,re.MULTILINE))
print(re.findall(r"world$",b,re.MULTILINE))
print(b)
# Out:
# ['world']
# ['world', 'world', 'world']
# hello world
#
# hello world
#
# hello world

# %%
d = "a ab abb abab ababab"   
print(re.findall(r"ab*",d))
print(re.findall(r"b*",d))
print(re.findall(r"(ab)*",d))
# Out:
# ['a', 'ab', 'abb', 'ab', 'ab', 'ab', 'ab', 'ab']
# ['', '', '', 'b', '', '', 'bb', '', '', 'b', '', 'b', '', '', 'b', '', 'b', '', 'b', '']
# ['', '', 'ab', '', 'ab', '', '', 'ab', '', 'ab', '']

# %%
e = "a aab abb abbb"
print(re.findall(r"ab+",e))
print(re.findall(r"a+b+",e))
print(re.findall(r"a+b",e))
print(re.findall(r"(a+)",e))
# Out:
# ['ab', 'abb', 'abbb']
# ['aab', 'abb', 'abbb']
# ['aab', 'ab', 'ab']
# ['a', 'aa', 'a', 'a']

# %%
f = "MM M MMM"

print(re.findall(r"M{2,}",f)) # two or more
print(re.findall(r"M{2}",f))
# Out:
# ['MM', 'MMM']
# ['MM', 'MM']

# %%
print(re.findall(r"\w+.{2}\w+","pattern"))
print(re.findall(r"\w+.{2}\w+","hello"))
# Out:
# ['pattern']
# ['hello']

# %%
g = "abcdef"
print(re.findall(r"[a-c]",g))
print(re.findall(r"[a-c]+",g))
print(re.findall(r"^[a-c]+",g))
# Out:
# ['a', 'b', 'c']
# ['abc']
# ['abc']

# %%
g = "apple \nball \ncat \ndog \negg \nfish"
print(re.findall(r"^[a-c]\w+",g,re.M))
print(g)
# Out:
# ['apple', 'ball', 'cat']
# apple
# ball
# cat
# dog
# egg
# fish

# %%
h = "abc123.abc123"
print(re.findall(r"\d+",h))
print(re.findall(r"\w+",h))
print(re.findall(r"\..+",h))
# Out:
# ['123', '123']
# ['abc123', 'abc123']
# ['.abc123']

# %%
k = "apple iphone samsung Apple color colour"
print(re.findall(r"apple|Apple",k))
print(re.findall(r"color|colour",k))
# Out:
# ['apple', 'Apple']
# ['color', 'colour']

# %%
l =  "ab abab python ababab"
print(re.findall(r"(ab).+",l))
print(re.findall(r"abab\s(.+)\s",l))
# Out:
# ['ab']
# ['python']

# %% [markdown]
# # Special Sequences
# - A special sequence is a \ followed by one of the characters in the list below, and has a special       meaning:
#
#   1. `\d` : Matches any decimal digit; this is equivalent to the class [0-9].
#   2. `\D` : Matches any non-digit character; this is equivalent to the class [^0-9].
#   3. `\s` : Matches any whitespace character, next line character(\n) or tab(\t);
#   4. `\S` : Matches any non-whitespace character;
#   5. `\w` : Matches any alphanumeric (word) character; this is equivalent to the class [a-zA-Z0-9_].
#   6. `\W` : Matches any non-alphanumeric character; this is equivalent to the class [^a-zA-Z0-9_].

# %%
d1 = "ID123"
print(re.findall(r"\d+",d1))
# Out:
# ['123']

# %%
e1 = """ID123#*$%"""
print(re.findall(r"\D+",e1))
# Out:
# ['ID', '#*$%']

# %%
f1 = "a b\tc\nd"
print(f1)
print(re.findall(r"\s+",f1))
# Out:
# a b	c
# d
# [' ', '\t', '\n']

# %%
g1 = "a b\tc\nd @#$"
print(re.findall(r"\S+",g1))
# Out:
# ['a', 'b', 'c', 'd', '@#$']

# %%
h1 = "user_123@jio"
print(re.findall(r"\w+",h1))
# Out:
# ['user_123', 'jio']

# %%
h1 = "user_123"
print(re.findall(r"\W+",h1))
# Out:
# []

# %%
i1 = "user@123 %& *("
print(re.findall(r"\W+",i1))
# Out:
# ['@', ' %& *(']

# %% [markdown]
# #### Some examples for set
#  1. `[arn]` Returns a match where one of the specified characters (a, r, or n) are present
#  2. `[a-n]` Returns a match for any lower case character, alphabetically between a and n
#  3. `[^arn]` Returns a match for any character EXCEPT a, r, and n
#  4. `[0123]` Returns a match where any of the specified digits (0, 1, 2, or 3) are present
#  5. `[0-9]` Returns a match for any digit between 0 and 9
#  6. `0-5` Returns a match for any two-digit numbers from 00 and 59
#  7. `[a-zA-Z]` Returns a match for any character alphabetically between a and z, lower case OR upper      case

# %%
colleges="""college : IIT Madras - Indian Institute of Technology
4.6(202)
Fees: ₹ 10.00 Lakh
Salary : ₹ 16.00 Lakh
Not Ranked
Times ' 22
3
The Week ' 21
1
Outlook ' 20
Admissions
Courses & Fees
Placements 0-5
college : IIT Madras - Indian Institute of Technology
4.1(202)
Fees: ₹ 10.00 Lakh
Salary : ₹ 16.00 Lakh
Not Ranked
Times ' 22
3
The Week ' 21
1
Outlook ' 20
Admissions
Courses & Fees
Placements 0-5
college : IIT Madras - Indian Institute of Technology
4.4(202)
Fees: ₹ 10.00 Lakh
Salary : ₹ 16.00 Lakh
Not Ranked
Times ' 22
3
The Week ' 21
1
Outlook ' 20
Admissions
Courses & Fees
Placements 0-5"""

# %%
# extract college name
print(re.findall(r"college : (.+)",colleges))
print(re.findall(r"college\s\W+\s(.+)",colleges))
# Out:
# ['IIT Madras - Indian Institute of Technology', 'IIT Madras - Indian Institute of Technology', 'IIT Madras - Indian Institute of Technology']
# ['IIT Madras - Indian Institute of Technology', 'IIT Madras - Indian Institute of Technology', 'IIT Madras - Indian Institute of Technology']

# %%
# extract the fees
print(re.findall(r"Fees: (.+)",colleges))
print(re.findall(r"Fees: \W+(.+) Lakh",colleges))
print(re.findall(r"Fees: \W+(\d+.\d+)",colleges))
# Out:
# ['₹ 10.00 Lakh', '₹ 10.00 Lakh', '₹ 10.00 Lakh']
# ['10.00', '10.00', '10.00']
# ['10.00', '10.00', '10.00']

# %%
# extact the Placements
print(re.findall(r"Placements\s(.+)",colleges))
print(re.findall(r"Placements\s(\d+\D+\d+)",colleges))
print(re.findall(r"Placements\s(\d+\W+\d+)",colleges))
print(re.findall(r"Placements\s(\d+.\d+)",colleges))
# Out:
# ['0-5', '0-5', '0-5']
# ['0-5', '0-5', '0-5']
# ['0-5', '0-5', '0-5']
# ['0-5', '0-5', '0-5']

# %%
print(re.findall(r"(\d+.\d+)\(",colleges))
# Out:
# ['4.6', '4.1', '4.4']

# %%
emails="""python@gmail.com
python_sql@gmail.com
python.sql@ gmail.com
python1234@gmail.com
python@outlook.com
python_sql@outlook.com
python.sql@outlook.com
python1234@outlook.com
python@yahoo.org
python_sql@yahoo.com
python.sql@yahoo.in
python1234@yahoo.com
"""

# %%
#Extracting username of all emails
# Extract usernames which has number in it
#Extracting domain of all emails
#Extracting com,org,in of all emails
#Extracting emails of outlook 
#Extracting all emails

# %%
#Extracting username of all emails
import re
print(re.findall(r"(\w+)@",emails))
# Out:
# ['python', 'python_sql', 'sql', 'python1234', 'python', 'python_sql', 'sql', 'python1234', 'python', 'python_sql', 'sql', 'python1234']

# %%
# Extract usernames which has number in it
print(re.findall(r"(.+\d+)@",emails))
# Out:
# ['python1234', 'python1234', 'python1234']

# %%
#Extracting domain of all emails
print(re.findall(r"@(\w+).",emails))
# Out:
# ['gmail', 'gmail', 'gmail', 'outlook', 'outlook', 'outlook', 'outlook', 'yahoo', 'yahoo', 'yahoo', 'yahoo']

# %%
#Extracting com,org,in of all emails
print(re.findall(r"@.+\.(\w+)",emails))
# Out:
# ['com', 'com', 'com', 'com', 'com', 'com', 'com', 'com', 'org', 'com', 'in', 'com']

# %%
print(re.findall(r".+outlook.+",emails))
# Out:
# ['python@outlook.com', 'python_sql@outlook.com', 'python.sql@outlook.com', 'python1234@outlook.com']

# %%
phones="""SAMSUNG Galaxy F23 5G (Forest Green, 128 GB)
SAMSUNG Galaxy F04 (Jade Purple, 64 GB)
POCO M3 Pro 5G (Yellow, 128 GB)
MOTOROLA e40 (Carbon Gray, 64 GB)
APPLE iPhone 13 (Blue, 128 GB)
APPLE iPhone 14 (Starlight, 128 GB)
APPLE iPhone 14 (Blue, 128 GB)
MOTOROLA G62 5G (Midnight Gray, 128 GB)
REDMI 10 (Pacific Blue, 64 GB)
REDMI 10 (Caribbean Green, 64 GB)
REDMI Note 11 SE (Cosmic White, 64 GB)
MOTOROLA G32 (Mineral Gray, 64 GB)
MOTOROLA G62 5G (Frosted Blue, 128 GB)
POCO C31 (Royal Blue, 64 GB)
MOTOROLA e40 (Pink Clay, 64 GB)
REDMI 10 (Midnight Black, 64 GB)
SAMSUNG Galaxy F23 5G (Copper Blush, 128 GB)
REDMI Note 12 Pro+ 5G (Obsidian Black, 256 GB)
SAMSUNG Galaxy F04 (Opal Green, 64 GB)
MOTOROLA G32 (Satin Silver, 64 GB)
POCO M4 Pro (Cool Blue, 64 GB)
REDMI 9i Sport (Coral Green, 64 GB)
SAMSUNG Galaxy F23 5G (Forest Green, 128 GB)
POCO M4 Pro (Cool Blue, 128 GB)"""

# %%
#Extracting mobile Brands
#Extracting the mobile version
#Extracting storage of mobile phones
#Extracting color of mobile phones

# %% [markdown]
# # Functions

# %% [markdown]
# `findall()` : Returns a list containing all matches
# >  **syntax** : re.findall (pattern, target string)
#
# `search` : Searches for the first match anywhere in the string.
# `match` : Matches only at the beginning of the string.
# `split`      : Splits string based on a regex pattern.
# `sub`        : Replaces matched patterns.
# `subn`       : Same as `sub()`, but also returns count of replacements..

# %%
import re

# %%
a = "ID 123 and 45"

# %%
re.findall(r"\d+",a)
# Out:
# ['123', '45']

# %%
print(re.search(r"\d+",a))
print(re.search(r"\d+",a).group())
print(re.search(r"\s(\d+)\s\w+\s(\d+)",a).groups())
print(re.search(r"\s(\d+)\s\w+\s(\d+)",a).group())
print(re.search(r"\s(\d+)\s\w+\s(\d+)",a).groups()[0])
print(re.search(r"\s(\d+)\s\w+\s(\d+)",a).span())
# Out:
# <re.Match object; span=(3, 6), match='123'>
# 123
# ('123', '45')
#  123 and 45
# 123
# (2, 13)

# %%
a = "ID 123 and 45"
print(re.match(r"\d+",a))
print(re.match(r"\w+\s+(\d+)",a).group())
print(re.match(r"(\w+)\s+(\d+)",a).groups(1))
print(re.match(r"(\w+)\s+(\d+)",a).group(2))
# Out:
# None
# ID 123
# ('ID', '123')
# 123

# %%
str1 = "123 and 45"
re.match(r"\d+",str1)
# Out:
# <re.Match object; span=(0, 3), match='123'>

# %%
str2 = "ID   123 and 45"
str3 = "ID%123 and$45"

print(re.split(r"\s+",str2))
print(re.split(r"\s+",str3))
print(re.split(r"\W+",str3))
print(re.split(r"\w+",str3))
# Out:
# ['ID', '123', 'and', '45']
# ['ID%123', 'and$45']
# ['ID', '123', 'and', '45']
# ['', '%', ' ', '$', '']

# %%
str3 = "ID%123 and$45"
re.sub(r"\W+","*",str3) # ("regex","parameter",string)
# Out:
# 'ID*123*and*45'

# %%
str3 = "ID%123 and$45"
re.subn(r"\W+","*",str3)
# Out:
# ('ID*123*and*45', 3)

# %% [markdown]
# # Flages
#
# Regex flags modify how a pattern is interpreted.
# They are passed as an optional argument to regex functions.
#
# > **syntax:** re.findall(pattern, string, flags)
#
# - `re.I or re.IGNORECASE` : Makes pattern case-insensitive.
# - `re.M or re.MULTILINE`  : Changes behavior of `^` and `$` to match each line, not just entire string.
# - `re.S or re.DOTALL`     : Makes `.` match newline `(\n)` also.
# - `re.X or re.VERBOSE`    : Allows whitespace and comments in regex for readability.
# - `re.A or re.ASCII`      : Makes `\w, \d, \s, \b` match ASCII only.

# %%
s1 = "Python PYTHON python"

print(re.findall(r"python",s1,re.IGNORECASE))
print(re.findall(r"python",s1))
# Out:
# ['Python', 'PYTHON', 'python']
# ['python']

# %%
text = """hello
world
hello"""

print(re.findall(r"^w",text,re.M))
# Out:
# ['w']

# %%
text = "hello\nworld"
print(re.findall(r"\w+",text))
print(re.findall(r".+",text))
print(re.findall(r"\w+\W+\w+",text))
print(re.findall(r".+",text,re.S))
print(re.findall(r"\w+",text,re.S)) #a-z-0-9-_
print(re.findall(r".+",text,re.DOTALL))
# Out:
# ['hello', 'world']
# ['hello', 'world']
# ['hello\nworld']
# ['hello\nworld']
# ['hello', 'world']
# ['hello\nworld']

# %%
pattern = r"""
\d{3}      # area code
-          # dash
\d{3}      # first 3 digits
-          # dash
\d{4}      # last 4 digits
"""
s2 = "123-456-7890"

print(re.findall("\d+-\d+-\d+",s2))
print(re.findall("\d{3}-\d{3}-\d{4}",s2))
print(re.findall(".+",s2))
print(re.findall(pattern,s2,re.VERBOSE))
print(re.findall(pattern,s2))
# Out:
# ['123-456-7890']
# ['123-456-7890']
# ['123-456-7890']
# ['123-456-7890']
# []

# %%
s3 = "naïve café %^"
re.findall(r"\w+",s3,re.A)
# Out:
# ['na', 've', 'caf']

# %% [markdown]
# ### TASK

# %%
# Extract all numbers from the text.
text = "Order123 shipped on 25-08-2025 with ID4567"

print(re.findall("\d+",text))

# Extracting the date
print(re.findall("\d{2}[-]\d{2}[-]\d{4}",text))
print(re.findall("\d{2}-\d{2}-\d{4}",text))
print(re.findall("\d+\W+\d+\W+\d+",text))
# Out:
# ['123', '25', '08', '2025', '4567']
# ['25-08-2025']
# ['25-08-2025']
# ['25-08-2025']

# %%
# Extract only 10-digit phone numbers.
phones = "9876543210, 12345, 9123456789, 999"
print(re.findall("\d{10}",phones))
# Out:
# ['9876543210', '9123456789']

# %%
# Match all occurrences of "python" ignoring case.
text = "Python python PYTHON PyThOn"

print(re.findall("python",text,re.IGNORECASE))
print(re.findall(r".+",text,re.IGNORECASE))
print(re.findall(r"python", text, re.IGNORECASE))
print(re.findall('python',text,re.I))
# Out:
# ['Python', 'python', 'PYTHON', 'PyThOn']
# ['Python python PYTHON PyThOn']
# ['Python', 'python', 'PYTHON', 'PyThOn']
# ['Python', 'python', 'PYTHON', 'PyThOn']

# %%
# Match only standalone word "cat".
# Match "cat" inside words.
sentence = "cat scAtter copycat cat"

print(re.findall(r"\bcat",sentence,re.I))
print(re.findall(r"\bcat\b",sentence,re.I))
print(re.findall(r"cat\b",sentence,re.I))
print(re.findall(r"\Bcat\B",sentence,re.I))
# Out:
# ['cat', 'cat']
# ['cat', 'cat']
# ['cat', 'cat', 'cat']
# ['cAt']

# %%
# Replace all digits with *.
data = "User123 has balance 4500"
print(re.sub(r'\d','*',data))
# Out:
# User*** has balance ****

# %%
# Extract all lines starting with "error".
text = """error: file missing
info: process started
error: permission denied"""

# %%
# Match everything from "start" to "end".
text = "start\nmiddle\nend"

# %%
# Extract all email urseid's
emails = "test@gmail.com admin@yahoo.in user@company.org"

# %%
#Check which IDs contain only digits and are exactly 5 characters long.
ids = ["12345", "1234a", "67890"]

# %%
# Write a readable regex to match phone numbers like:
num = "123-456-7890"

# %%
# Extract the error part
# Extract the paths as well
log = "ERROR 404 at /home | INFO 200 at /login | ERROR 500 at /api"
