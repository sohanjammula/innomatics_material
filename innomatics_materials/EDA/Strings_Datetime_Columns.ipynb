# %% [markdown]
# ### Stings methods in pandas
#
# - Pandas dataframe we have columns that contain string values. Pandas provides an easy way of applying string methods to whole columns which are just pandas series objects. We can access the values of these series objects (or columns) as strings and apply string methods to them by using the `str` attribute of the series. Let’s look at some examples here.

# %%
import pandas as pd
import warnings 
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv(r"data\Titanic.csv")

# %%
df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
df['Name'].str.len()-df['Name'].str.replace(' ',"").str.len()
# Out:
# 0      2
# 1      4
# 2      3
# 3      2
# 4      5
#       ..
# 413    2
# 414    4
# 415    3
# 416    2
# 417    3
# Name: Name, Length: 418, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %% [markdown]
# - Here `Name` column in dataframe is a string datatype

# %% [markdown]
# **Applying String Methods to a Column**
#
# - To apply a string method to a column, we will be using the str attribute of that Series object. So in general, we will be using the following format:
#
# `Series.str.string(Method|Function)`

# %%
df["Name"]
# Out:
# 0                                  Kelly, Mr. James
# 1                  Wilkes, Mrs. James (Ellen Needs)
# 2                         Myles, Mr. Thomas Francis
# 3                                  Wirz, Mr. Albert
# 4      Hirvonen, Mrs. Alexander (Helga E Lindqvist)
#                            ...
# 413                              Spector, Mr. Woolf
# 414                    Oliva y Ocana, Dona. Fermina
# 415                    Saether, Mr. Simon Sivertsen
# 416                             Ware, Mr. Frederick
# 417                        Peter, Master. Michael J
# Name: Name, Length: 418, dtype: object

# %%
df["Name"].str.upper()         #Complete text has changed to upper letters
# Out:
# 0                                  KELLY, MR. JAMES
# 1                  WILKES, MRS. JAMES (ELLEN NEEDS)
# 2                         MYLES, MR. THOMAS FRANCIS
# 3                                  WIRZ, MR. ALBERT
# 4      HIRVONEN, MRS. ALEXANDER (HELGA E LINDQVIST)
#                            ...
# 413                              SPECTOR, MR. WOOLF
# 414                    OLIVA Y OCANA, DONA. FERMINA
# 415                    SAETHER, MR. SIMON SIVERTSEN
# 416                             WARE, MR. FREDERICK
# 417                        PETER, MASTER. MICHAEL J
# Name: Name, Length: 418, dtype: object

# %%
df["Name"].str.capitalize()
# Out:
# 0                                  Kelly, mr. james
# 1                  Wilkes, mrs. james (ellen needs)
# 2                         Myles, mr. thomas francis
# 3                                  Wirz, mr. albert
# 4      Hirvonen, mrs. alexander (helga e lindqvist)
#                            ...
# 413                              Spector, mr. woolf
# 414                    Oliva y ocana, dona. fermina
# 415                    Saether, mr. simon sivertsen
# 416                             Ware, mr. frederick
# 417                        Peter, master. michael j
# Name: Name, Length: 418, dtype: object

# %% [markdown]
# **Replacing Characters in a Column**
#
#
# - What if we want to replace all comma(,) in the Name column with an underscore? We can perform this by using the replace method. We just specify what we want to replace and then what we want to replace it with.
#
# `Series.str.replace(",","_")`

# %%
df["Name"].str.replace(",","_")      #ALl the comma's in Name column are repalced with underscore
# Out:
# 0                                  Kelly_ Mr. James
# 1                  Wilkes_ Mrs. James (Ellen Needs)
# 2                         Myles_ Mr. Thomas Francis
# 3                                  Wirz_ Mr. Albert
# 4      Hirvonen_ Mrs. Alexander (Helga E Lindqvist)
#                            ...
# 413                              Spector_ Mr. Woolf
# 414                    Oliva y Ocana_ Dona. Fermina
# 415                    Saether_ Mr. Simon Sivertsen
# 416                             Ware_ Mr. Frederick
# 417                        Peter_ Master. Michael J
# Name: Name, Length: 418, dtype: object

# %% [markdown]
# **Chaining Methods**
#
# - We can also chain string methods together. Remember that these Series methods return a pandas Series object. So we can just add another string method to them. For example, let’s say that we want to replace all comma(,) with an underscore and change all the Names to lowercase. We can accomplish this with the following code:

# %%
df["Name"].str.replace(",","_").str.lower()
# Out:
# 0                                  kelly_ mr. james
# 1                  wilkes_ mrs. james (ellen needs)
# 2                         myles_ mr. thomas francis
# 3                                  wirz_ mr. albert
# 4      hirvonen_ mrs. alexander (helga e lindqvist)
#                            ...
# 413                              spector_ mr. woolf
# 414                    oliva y ocana_ dona. fermina
# 415                    saether_ mr. simon sivertsen
# 416                             ware_ mr. frederick
# 417                        peter_ master. michael j
# Name: Name, Length: 418, dtype: object

# %% [markdown]
# **Creating a new column with `length of Name` in the dataframe**

# %%
df["Name_Length"]=df["Name"].str.len()

# %%
df      #Added a new col with length of name at last col of dataframe
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked  \
# ...

# %% [markdown]
# **Extracting Gender without using "Sex" column**
#
# - Note that we need the escape character "\" to look for the ".".  We can easily the results of the returned series in a new column as follows.

# %%
df[df["Name"].str.contains("Mr\.")]     #ALl the male data without using "Sex" column
# Out:
#      PassengerId  Pclass                          Name   Sex   Age  SibSp  \
# 0            892       3              Kelly, Mr. James  male  34.5      0
# 2            894       2     Myles, Mr. Thomas Francis  male  62.0      0
# 3            895       3              Wirz, Mr. Albert  male  27.0      0
# 5            897       3    Svensson, Mr. Johan Cervin  male  14.0      0
# 7            899       2  Caldwell, Mr. Albert Francis  male  26.0      1
# ..           ...     ...                           ...   ...   ...    ...
# 406         1298       2     Ware, Mr. William Jeffery  male  23.0      1
# 407         1299       1    Widener, Mr. George Dunton  male  50.0      1
# 413         1305       3            Spector, Mr. Woolf  male   NaN      0
# 415         1307       3  Saether, Mr. Simon Sivertsen  male  38.5      0
# 416         1308       3           Ware, Mr. Frederick  male   NaN      0
#
#      Parch              Ticket      Fare Cabin Embarked
# ...

# %% [markdown]
# **Separation of first Name and last Name in the Name Column**

# %%
df["Name"]
# Out:
# 0                                  Kelly, Mr. James
# 1                  Wilkes, Mrs. James (Ellen Needs)
# 2                         Myles, Mr. Thomas Francis
# 3                                  Wirz, Mr. Albert
# 4      Hirvonen, Mrs. Alexander (Helga E Lindqvist)
#                            ...
# 413                              Spector, Mr. Woolf
# 414                    Oliva y Ocana, Dona. Fermina
# 415                    Saether, Mr. Simon Sivertsen
# 416                             Ware, Mr. Frederick
# 417                        Peter, Master. Michael J
# Name: Name, Length: 418, dtype: object

# %%
df["Name"].str.split(",",expand=True)
                                             #Both first and last names are separated
# Out:
#                  0                                    1
# 0            Kelly                            Mr. James
# 1           Wilkes             Mrs. James (Ellen Needs)
# 2            Myles                   Mr. Thomas Francis
# 3             Wirz                           Mr. Albert
# 4         Hirvonen   Mrs. Alexander (Helga E Lindqvist)
# ..             ...                                  ...
# 413        Spector                            Mr. Woolf
# 414  Oliva y Ocana                        Dona. Fermina
# 415        Saether                  Mr. Simon Sivertsen
# 416           Ware                        Mr. Frederick
# 417          Peter                    Master. Michael J
#
# [418 rows x 2 columns]

# %%
import pandas as pd

# %%
df=pd.read_csv(r"data\Titanic.csv")

# %%
df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %% [markdown]
# **Requirement**
#
# - Now Based on one column we want to create a new column, for example `Sex column` contains two values Male|Female now i want to create a column where Male=1 and Female=0.
#
# - The General way to do this is

# %%
gender=[]
for i in df["Sex"]:
    if i=="male":
        gender.append(1)
    elif i=="female":
        gender.append(0)
df["Gender"]=gender

# %%
df                #We created a new column with male=1 and female=0
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked  \
# ...

# %% [markdown]
# - Same requirement can be done by `Map` and `Apply` functions.

# %% [markdown]
# **Map function**
#
# - In map function lets us map values in a column to other values. Let's use map to create a binary column that is 1 for males and 0 for females. We give the mapping that we want by providing the appropriate dictionary

# %%
df["gender_Map"] = df["Sex"].map({"male" : 1, "female" : 0})

# %%
df        #Created a new column with same requirement
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked  \
# ...

# %% [markdown]
# **Map with lambda**

# %%
df["gender_Map&lambda"] = df["Sex"].map(lambda x: 1 if x=="male" else 0)

# %%
df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked  \
# ...

# %% [markdown]
# **Apply Function**
#
# - Apply function also works same as Map function

# %%
df["gender_apply"] = df["Sex"].apply(lambda x: 1 if x=="male" else 0)

# %%
df        #Created a New Column using apply function
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked  \
# ...

# %% [markdown]
# # Pandas DATE TIME

# %%
import numpy as np

import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
data = {"Car": ["BMW", "ALTO", "AUDI","MARUTI", "HONDA", "HYUNDAI", "FORD", "KIA"],\
     "Color": ["Red", "Yellow", "Black", "Green", "Black", "Red", "Black", "Black"],\
     "Year": ["1990", "1980", "2003", "2000", "2001", "2004", "1999", "2020"],\
     "Rating": ["2.5", "1.5", "3.8", "9.7", "8.9", "3.2", "5.5", "6.9"],\
     "Date": ["30/04/2023", "31/08/1999", "28/12/2015", "29/06/2011",\
                 "30/12/2020", "31/07/2013", "28/11/2000", "25/12/2020"]}
df = pd.DataFrame(data)
df.head()
# Out:
#       Car   Color  Year Rating        Date
# 0     BMW     Red  1990    2.5  30/04/2023
# 1    ALTO  Yellow  1980    1.5  31/08/1999
# 2    AUDI   Black  2003    3.8  28/12/2015
# 3  MARUTI   Green  2000    9.7  29/06/2011
# 4   HONDA   Black  2001    8.9  30/12/2020

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Car     8 non-null      object
#  1   Color   8 non-null      object
#  2   Year    8 non-null      object
#  3   Rating  8 non-null      object
#  4   Date    8 non-null      object
# dtypes: object(5)
# memory usage: 448.0+ bytes

# %%
#Reset the column Issue Date to be a datetime

df["Date"] = pd.to_datetime(df["Date"])
#Lets convert the Date column to be a datetime and not a string!

# %%
df
# Out:
#        Car   Color  Year Rating       Date
# 0      BMW     Red  1990    2.5 2023-04-30
# 1     ALTO  Yellow  1980    1.5 1999-08-31
# 2     AUDI   Black  2003    3.8 2015-12-28
# 3   MARUTI   Green  2000    9.7 2011-06-29
# 4    HONDA   Black  2001    8.9 2020-12-30
# 5  HYUNDAI     Red  2004    3.2 2013-07-31
# 6     FORD   Black  1999    5.5 2000-11-28
# 7      KIA   Black  2020    6.9 2020-12-25

# %%
df.info()    #now datetime64[ns] is a datetime datatype in pandas
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Car     8 non-null      object
#  1   Color   8 non-null      object
#  2   Year    8 non-null      object
#  3   Rating  8 non-null      object
#  4   Date    8 non-null      datetime64[ns]
# dtypes: datetime64[ns](1), object(4)
# memory usage: 448.0+ bytes

# %% [markdown]
# ## date_range()
# - ##### pandas.date_range() is one of the general functions in Pandas which is used to return a fixed frequency DatetimeIndex.

# %%
# Day wise
print(pd.date_range('2000/1/11', periods=6,freq='y'))
# Out:
# DatetimeIndex(['2000-12-31', '2001-12-31', '2002-12-31', '2003-12-31',
#                '2004-12-31', '2005-12-31'],
#               dtype='datetime64[ns]', freq='A-DEC')

# %%
#Month wise
print(pd.date_range('1/1/2011', periods=5,freq='m'))
# Out:
# DatetimeIndex(['2011-01-31', '2011-02-28', '2011-03-31', '2011-04-30',
#                '2011-05-31'],
#               dtype='datetime64[ns]', freq='M')

# %%
#Create  a datetime datatype with specified intervals

start = pd.datetime(2011, 1, 1)
print('Start :',start)

end = pd.datetime(2012, 1, 20)
print("Stop :",end)

print(pd.date_range(start, end,freq='m'))
# Out:
# Start : 2011-01-01 00:00:00
# Stop : 2012-01-20 00:00:00
# DatetimeIndex(['2011-01-31', '2011-02-28', '2011-03-31', '2011-04-30',
#                '2011-05-31', '2011-06-30', '2011-07-31', '2011-08-31',
#                '2011-09-30', '2011-10-31', '2011-11-30', '2011-12-31'],
#               dtype='datetime64[ns]', freq='M')

# %%
#Creating a datframe With date column

df = pd.DataFrame({'name': ['Tom', 'Andy', 'Lucas'],
                 'DoB': ['08-05-1997', '04-28-1996', '12/16/1995']})

# %%
df
# Out:
#     name         DoB
# 0    Tom  08-05-1997
# 1   Andy  04-28-1996
# 2  Lucas  12/16/1995

# %%
#Converting date column as datetime column

df['DoB'] = pd.to_datetime(df['DoB'])

# %%
df
# Out:
#     name        DoB
# 0    Tom 1997-08-05
# 1   Andy 1996-04-28
# 2  Lucas 1995-12-16

# %%
#To get only year values in the date column

df['DoB'].dt.year
# Out:
# 0    1997
# 1    1996
# 2    1995
# Name: DoB, dtype: int64

# %%
#Checking the present year

today = pd.to_datetime('today')
today.year
# Out:
# 2025

# %%
#finding the difference between the present year and year in the dataframe

today.year - df['DoB'].dt.year
# Out:
# 0    28
# 1    29
# 2    30
# Name: DoB, dtype: int64

# %%
#Creating new column on the difference years

df["Age"] = today.year - df['DoB'].dt.year
df
# Out:
#     name        DoB  Age
# 0    Tom 1997-08-05   28
# 1   Andy 1996-04-28   29
# 2  Lucas 1995-12-16   30

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    3 non-null      object
#  1   DoB     3 non-null      datetime64[ns]
#  2   Age     3 non-null      int64
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 200.0+ bytes

# %%
df["DoB"]
# Out:
# 0   1997-08-05
# 1   1996-04-28
# 2   1995-12-16
# Name: DoB, dtype: datetime64[ns]

# %%
df['DoB'].dt.year        #Checking year
# Out:
# 0    1997
# 1    1996
# 2    1995
# Name: DoB, dtype: int64

# %%
df['DoB'].dt.day          #Checking day
# Out:
# 0     5
# 1    28
# 2    16
# Name: DoB, dtype: int64

# %%
df['DoB'].dt.month        #Checking month
# Out:
# 0     8
# 1     4
# 2    12
# Name: DoB, dtype: int64

# %%
df['DoB'].dt.day_name()        #Checking the day_name
# Out:
# 0     Tuesday
# 1      Sunday
# 2    Saturday
# Name: DoB, dtype: object

# %% [markdown]
# ## Plotting with Pandas
#
# - For a quick Visualization we no need to use visualization libraries like matplotlib and seaborn. `pandas will provide some quick visualization plots`.
#
# - Syntax - `Dataframe['column'].plot(kind = "")`
#   - `Datraframe['column'].plot.plotname`
#
#
# - Common parameters in `.plot` are x,y,figsize,title,xticks,yticks,legend etc.... some are based on plots.
#
#
# - The kind of plot to produce:
#
# 1. `line` : line plot (default)
# 2. `bar`: vertical bar plot
# 3. `barh` : horizontal bar plot
# 4. `hist` : histogram
# 5. `box` : boxplot
# 6. `kde` : Kernel Density Estimation plot
# 7. `density` : same as ‘kde’
# 8. `area` : area plot
# 9. `pie` : pie plot
# 10. `scatter` : scatter plot
# 11. `hexbin` : hexbin plot

# %%
import pandas as pd

# %%
df=pd.read_csv("data\Titanic.csv")

# %%
df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %% [markdown]
# **Line plot**
#
# - used to display a frequency of data along a line segment

# %%
df["Age"].fillna(df["Age"].mean(),inplace=True)
df["Age"].iloc[:40].plot(kind="line",figsize=(10,5),c="r",ylabel="Age")
# Out:
# <Axes: ylabel='Age'>

# %%
## Plotting with Pandas

- For a quick Visualization we no need to use visualization libraries like matplotlib and seaborn. `pandas will provide some quick visualization plots`. 

- Syntax - `Dataframe['column'].plot(kind = "")`
  - `Datraframe['column'].plot.plotname`
  
  
- Common parameters in `.plot` are x,y,figsize,title,xticks,yticks,legend etc.... some are based on plots.


- The kind of plot to produce:

1. `line` : line plot (default) 
2. `bar`: vertical bar plot
3. `barh` : horizontal bar plot
4. `hist` : histogram
5. `box` : boxplot
6. `kde` : Kernel Density Estimation plot
7. `density` : same as ‘kde’
8. `area` : area plot
9. `pie` : pie plot
10. `scatter` : scatter plot
11. `hexbin` : hexbin plot

import pandas as pd


df=pd.read_csv("data\Titanic.csv")

df

**Line plot**

- used to display a frequency of data along a line segment

df["Age"].fillna(df["Age"].mean(),inplace=True)
df["Age"].iloc[:40].plot(kind="line",figsize=(10,5),c="r",ylabel="Age")
