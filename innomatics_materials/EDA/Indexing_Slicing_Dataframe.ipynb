# %%
import pandas as pd

# %%
df=pd.read_csv(r'C:\Users\50094875\Documents\Python Core_With Code_Share (1)\Pandas\Pandas\data\Iris.csv')

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df.describe(include='object')
# Out:
#             Species
# count           150
# unique            3
# top     Iris-setosa
# freq             50

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.index
# Out:
# RangeIndex(start=0, stop=150, step=1)

# %%
df.shape
# Out:
# (150, 6)

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df[['SepalLengthCm','PetalLengthCm']].sum()
# Out:
# SepalLengthCm    876.5
# PetalLengthCm    563.8
# dtype: float64

# %%
df[['SepalLengthCm','PetalLengthCm']]
# Out:
#      SepalLengthCm  PetalLengthCm
# 0              5.1            1.4
# 1              4.9            1.4
# 2              4.7            1.3
# 3              4.6            1.5
# 4              5.0            1.4
# ..             ...            ...
# 145            6.7            5.2
# 146            6.3            5.0
# 147            6.5            5.2
# 148            6.2            5.4
# 149            5.9            5.1
#
# [150 rows x 2 columns]

# %%
df[['SepalLengthCm','PetalLengthCm']].sum(axis=1)
# Out:
# 0       6.5
# 1       6.3
# 2       6.0
# 3       6.1
# 4       6.4
#        ...
# 145    11.9
# 146    11.3
# 147    11.7
# 148    11.6
# 149    11.0
# Length: 150, dtype: float64

# %%
df['sum_length']=df[['SepalLengthCm','PetalLengthCm']].sum(axis=1)

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species  sum_length
# 0       Iris-setosa         6.5
# 1       Iris-setosa         6.3
# 2       Iris-setosa         6.0
# ...

# %%
df['avg_width']=df[['SepalWidthCm','PetalWidthCm']].mean(axis=1)

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species  sum_length  avg_width
# 0       Iris-setosa         6.5       1.85
# 1       Iris-setosa         6.3       1.60
# ...

# %%
df[['SepalLengthCm','SepalWidthCm','PetalLengthCm']].std()
# Out:
# SepalLengthCm    0.828066
# SepalWidthCm     0.433594
# PetalLengthCm    1.764420
# dtype: float64

# %%
df[['SepalLengthCm','SepalWidthCm','PetalLengthCm']].mean()
# Out:
# SepalLengthCm    5.843333
# SepalWidthCm     3.054000
# PetalLengthCm    3.758667
# dtype: float64

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species  sum_length  avg_width
# 0       Iris-setosa         6.5       1.85
# 1       Iris-setosa         6.3       1.60
# ...

# %%
df[df['SepalWidthCm']==df['SepalWidthCm'].max()]
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species  \
# 15  16            5.7           4.4            1.5           0.4  Iris-setosa
#
#     sum_length  avg_width
# 15         7.2        2.4

# %%
df['SepalWidthCm'].max()
# Out:
# 4.4

# %%
df['SepalWidthCm']
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: SepalWidthCm, Length: 150, dtype: float64

# %%
df['SepalWidthCm']==df['SepalWidthCm'].max()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 145    False
# 146    False
# 147    False
# 148    False
# 149    False
# Name: SepalWidthCm, Length: 150, dtype: bool

# %%
df2=df[df['Species']=='Iris-virginica']

# %%
df2
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 100  101            6.3           3.3            6.0           2.5
# 101  102            5.8           2.7            5.1           1.9
# 102  103            7.1           3.0            5.9           2.1
# 103  104            6.3           2.9            5.6           1.8
# 104  105            6.5           3.0            5.8           2.2
# 105  106            7.6           3.0            6.6           2.1
# 106  107            4.9           2.5            4.5           1.7
# 107  108            7.3           2.9            6.3           1.8
# 108  109            6.7           2.5            5.8           1.8
# 109  110            7.2           3.6            6.1           2.5
# 110  111            6.5           3.2            5.1           2.0
# 111  112            6.4           2.7            5.3           1.9
# 112  113            6.8           3.0            5.5           2.1
# ...

# %%
df.Species
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: Species, Length: 150, dtype: object

# %%
df[['Species','PetalLengthCm']]
# Out:
#             Species  PetalLengthCm
# 0       Iris-setosa            1.4
# 1       Iris-setosa            1.4
# 2       Iris-setosa            1.3
# 3       Iris-setosa            1.5
# 4       Iris-setosa            1.4
# ..              ...            ...
# 145  Iris-virginica            5.2
# 146  Iris-virginica            5.0
# 147  Iris-virginica            5.2
# 148  Iris-virginica            5.4
# 149  Iris-virginica            5.1
#
# [150 rows x 2 columns]

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species  sum_length  avg_width
# 0       Iris-setosa         6.5       1.85
# 1       Iris-setosa         6.3       1.60
# ...

# %%
df.iloc[25:51,:]
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 25  26            5.0           3.0            1.6           0.2
# 26  27            5.0           3.4            1.6           0.4
# 27  28            5.2           3.5            1.5           0.2
# 28  29            5.2           3.4            1.4           0.2
# 29  30            4.7           3.2            1.6           0.2
# 30  31            4.8           3.1            1.6           0.2
# 31  32            5.4           3.4            1.5           0.4
# 32  33            5.2           4.1            1.5           0.1
# 33  34            5.5           4.2            1.4           0.2
# 34  35            4.9           3.1            1.5           0.1
# 35  36            5.0           3.2            1.2           0.2
# 36  37            5.5           3.5            1.3           0.2
# 37  38            4.9           3.1            1.5           0.1
# ...

# %%
df.iloc[25:51,[2,4]]
# Out:
#     SepalWidthCm  PetalWidthCm
# 25           3.0           0.2
# 26           3.4           0.4
# 27           3.5           0.2
# 28           3.4           0.2
# 29           3.2           0.2
# 30           3.1           0.2
# 31           3.4           0.4
# 32           4.1           0.1
# 33           4.2           0.2
# 34           3.1           0.1
# 35           3.2           0.2
# 36           3.5           0.2
# 37           3.1           0.1
# 38           3.0           0.2
# 39           3.4           0.2
# 40           3.5           0.3
# 41           2.3           0.3
# 42           3.2           0.2
# 43           3.5           0.6
# 44           3.8           0.4
# 45           3.0           0.3
# 46           3.8           0.2
# 47           3.2           0.2
# 48           3.7           0.2
# 49           3.3           0.2
# 50           3.2           1.4

# %%
df.loc[25:51,['SepalWidthCm','PetalWidthCm']]
# Out:
#     SepalWidthCm  PetalWidthCm
# 25           3.0           0.2
# 26           3.4           0.4
# 27           3.5           0.2
# 28           3.4           0.2
# 29           3.2           0.2
# 30           3.1           0.2
# 31           3.4           0.4
# 32           4.1           0.1
# 33           4.2           0.2
# 34           3.1           0.1
# 35           3.2           0.2
# 36           3.5           0.2
# 37           3.1           0.1
# 38           3.0           0.2
# 39           3.4           0.2
# 40           3.5           0.3
# 41           2.3           0.3
# 42           3.2           0.2
# 43           3.5           0.6
# 44           3.8           0.4
# 45           3.0           0.3
# 46           3.8           0.2
# 47           3.2           0.2
# 48           3.7           0.2
# 49           3.3           0.2
# 50           3.2           1.4
# 51           3.2           1.5

# %%
df.iloc[:,[-1]]
# Out:
#      avg_width
# 0         1.85
# 1         1.60
# 2         1.70
# 3         1.65
# 4         1.90
# ..         ...
# 145       2.65
# 146       2.20
# 147       2.50
# 148       2.85
# 149       2.40
#
# [150 rows x 1 columns]

# %%
df.loc[df['SepalLengthCm']>5,['Species']]
# Out:
#             Species
# 0       Iris-setosa
# 5       Iris-setosa
# 10      Iris-setosa
# 14      Iris-setosa
# 15      Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [118 rows x 1 columns]

# %%
df[['SepalLengthCm','Species']]
# Out:
#      SepalLengthCm         Species
# 0              5.1     Iris-setosa
# 1              4.9     Iris-setosa
# 2              4.7     Iris-setosa
# 3              4.6     Iris-setosa
# 4              5.0     Iris-setosa
# ..             ...             ...
# 145            6.7  Iris-virginica
# 146            6.3  Iris-virginica
# 147            6.5  Iris-virginica
# 148            6.2  Iris-virginica
# 149            5.9  Iris-virginica
#
# [150 rows x 2 columns]

# %%
df[df['SepalLengthCm']>5]
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 5      6            5.4           3.9            1.7           0.4
# 10    11            5.4           3.7            1.5           0.2
# 14    15            5.8           4.0            1.2           0.2
# 15    16            5.7           4.4            1.5           0.4
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species  sum_length  avg_width
# 0       Iris-setosa         6.5       1.85
# 5       Iris-setosa         7.1       2.15
# ...

# %%
df[(df['SepalLengthCm']>5) & (df['PetalLengthCm']>5)]
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 83    84            6.0           2.7            5.1           1.6
# 100  101            6.3           3.3            6.0           2.5
# 101  102            5.8           2.7            5.1           1.9
# 102  103            7.1           3.0            5.9           2.1
# 103  104            6.3           2.9            5.6           1.8
# 104  105            6.5           3.0            5.8           2.2
# 105  106            7.6           3.0            6.6           2.1
# 107  108            7.3           2.9            6.3           1.8
# 108  109            6.7           2.5            5.8           1.8
# 109  110            7.2           3.6            6.1           2.5
# 110  111            6.5           3.2            5.1           2.0
# 111  112            6.4           2.7            5.3           1.9
# 112  113            6.8           3.0            5.5           2.1
# ...

# %%
df[(df['SepalLengthCm']>5)&(df['SepalLengthCm']<6)]
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 5      6            5.4           3.9            1.7           0.4
# 10    11            5.4           3.7            1.5           0.2
# 14    15            5.8           4.0            1.2           0.2
# 15    16            5.7           4.4            1.5           0.4
# 16    17            5.4           3.9            1.3           0.4
# 17    18            5.1           3.5            1.4           0.3
# 18    19            5.7           3.8            1.7           0.3
# 19    20            5.1           3.8            1.5           0.3
# 20    21            5.4           3.4            1.7           0.2
# 21    22            5.1           3.7            1.5           0.4
# 23    24            5.1           3.3            1.7           0.5
# 27    28            5.2           3.5            1.5           0.2
# ...

# %%
df[df['SepalLengthCm'].between(5,6)]
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 4      5            5.0           3.6            1.4           0.2
# 5      6            5.4           3.9            1.7           0.4
# 7      8            5.0           3.4            1.5           0.2
# 10    11            5.4           3.7            1.5           0.2
# ..   ...            ...           ...            ...           ...
# 119  120            6.0           2.2            5.0           1.5
# 121  122            5.6           2.8            4.9           2.0
# 138  139            6.0           3.0            4.8           1.8
# 142  143            5.8           2.7            5.1           1.9
# 149  150            5.9           3.0            5.1           1.8
#
#             Species  sum_length  avg_width
# 0       Iris-setosa         6.5       1.85
# 4       Iris-setosa         6.4       1.90
# ...

# %%
df[(df['SepalLengthCm']>5)|(df['PetalLengthCm']>5)]
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 5      6            5.4           3.9            1.7           0.4
# 10    11            5.4           3.7            1.5           0.2
# 14    15            5.8           4.0            1.2           0.2
# 15    16            5.7           4.4            1.5           0.4
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species  sum_length  avg_width
# 0       Iris-setosa         6.5       1.85
# 5       Iris-setosa         7.1       2.15
# ...

# %%
df['SepalWidthCm'].idxmax()
# Out:
# 15

# %%
df.iloc[[df['SepalWidthCm'].idxmax()]]
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species  \
# 15  16            5.7           4.4            1.5           0.4  Iris-setosa
#
#     sum_length  avg_width
# 15         7.2        2.4

# %%
df.iloc[[df['SepalWidthCm'].idxmin()]]
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 60  61            5.0           2.0            3.5           1.0
#
#             Species  sum_length  avg_width
# 60  Iris-versicolor         8.5        1.5

# %%
df[df['SepalLengthCm'].between(5,6)][['Species','PetalWidthCm']]
# Out:
#             Species  PetalWidthCm
# 0       Iris-setosa           0.2
# 4       Iris-setosa           0.2
# 5       Iris-setosa           0.4
# 7       Iris-setosa           0.2
# 10      Iris-setosa           0.2
# ..              ...           ...
# 119  Iris-virginica           1.5
# 121  Iris-virginica           2.0
# 138  Iris-virginica           1.8
# 142  Iris-virginica           1.9
# 149  Iris-virginica           1.8
#
# [67 rows x 2 columns]
