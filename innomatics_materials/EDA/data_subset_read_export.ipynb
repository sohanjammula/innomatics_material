# %%
import pandas as pd

# %%
df=pd.read_csv('C:\\Users\\Venugopal\\OneDrive\\Desktop\\Batch_423\\EDA\\data\\Iris.csv')

# %%
df2=pd.read_csv('C:/Users/Venugopal/OneDrive/Desktop/Batch_423/EDA/data/Iris.csv')

# %%
df3=pd.read_csv(r'C:\Users\Venugopal\OneDrive\Desktop\Batch_423\EDA\data\Iris.csv')

# %%
df3
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df_xl=pd.read_excel(r'C:\Users\Venugopal\OneDrive\Desktop\Batch_423\EDA\data\weather_data.xlsx')

# %%
df_xl
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
df=pd.read_csv(r'C:\Users\Venugopal\OneDrive\Desktop\Batch_423\EDA\data\std_data1.csv')

# %%
df
# Out:
#   SNAME  SCLASS   ENGLISH  COMPUTER  SCIENCE
# 0     A       10       67        66       66
# 1     B       12       87        56       65
# 2     C       11       66        89       63
# 3     D       10       56        88       66
# 4     E       10       89        90       56
# 5     F        9       88        85       89
# 6     G       12       90        83       88
# 7     H       11       79        88       90

# %%
df1=pd.read_csv(r'C:\Users\Venugopal\OneDrive\Desktop\Batch_423\EDA\data\std_data1.csv',usecols=['ENGLISH'])

# %%
df1
# Out:
#    ENGLISH
# 0       67
# 1       87
# 2       66
# 3       56
# 4       89
# 5       88
# 6       90
# 7       79

# %%
df2=pd.read_csv(r'C:\Users\Venugopal\OneDrive\Desktop\Batch_423\EDA\data\std_data1.csv',usecols=['SNAME','ENGLISH'])

# %%
df2
# Out:
#   SNAME  ENGLISH
# 0     A       67
# 1     B       87
# 2     C       66
# 3     D       56
# 4     E       89
# 5     F       88
# 6     G       90
# 7     H       79

# %%
df=pd.read_csv(r'C:\Users\Venugopal\OneDrive\Desktop\Batch_423\EDA\data\std_data1.csv',nrows=5)

# %%
df
# Out:
#   SNAME  SCLASS   ENGLISH  COMPUTER  SCIENCE
# 0     A       10       67        66       66
# 1     B       12       87        56       65
# 2     C       11       66        89       63
# 3     D       10       56        88       66
# 4     E       10       89        90       56

# %%
df=pd.read_csv(r'C:\Users\Venugopal\OneDrive\Desktop\Batch_423\EDA\data\std_data1.csv',nrows=5,usecols=['SNAME','ENGLISH'])

# %%
df
# Out:
#   SNAME  ENGLISH
# 0     A       67
# 1     B       87
# 2     C       66
# 3     D       56
# 4     E       89

# %%
df=pd.read_csv(r'C:\Users\Venugopal\OneDrive\Desktop\Batch_423\EDA\data\std_data2.csv')

# %%
df
# Out:
#   ABC SCHOOL Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4
# 0      SNAME    SCLASS     ENGLISH   COMPUTER    SCIENCE
# 1          A         10         67         66         66
# 2          B         12         87         56         65
# 3          C         11         66         89         63
# 4          D         10         56         88         66
# 5          E         10         89         90         56
# 6          F          9         88         85         89
# 7          G         12         90         83         88
# 8          H         11         79         88         90

# %%
df=pd.read_csv(r'C:\Users\Venugopal\OneDrive\Desktop\Batch_423\EDA\data\std_data2.csv',skiprows=1)

# %%
df
# Out:
#   SNAME  SCLASS   ENGLISH  COMPUTER  SCIENCE
# 0     A       10       67        66       66
# 1     B       12       87        56       65
# 2     C       11       66        89       63
# 3     D       10       56        88       66
# 4     E       10       89        90       56
# 5     F        9       88        85       89
# 6     G       12       90        83       88
# 7     H       11       79        88       90

# %%
df=pd.read_csv(r'C:\Users\Venugopal\OneDrive\Desktop\Batch_423\EDA\data\std_data2.csv',skiprows=2)
df
# Out:
#    A  10  67  66  66.1
# 0  B  12  87  56    65
# 1  C  11  66  89    63
# 2  D  10  56  88    66
# 3  E  10  89  90    56
# 4  F   9  88  85    89
# 5  G  12  90  83    88
# 6  H  11  79  88    90

# %%
df=pd.read_csv(r'C:\Users\Venugopal\OneDrive\Desktop\Batch_423\EDA\data\std_data1.csv',skiprows=[2])

# %%
df
# Out:
#   SNAME  SCLASS   ENGLISH  COMPUTER  SCIENCE
# 0     A       10       67        66       66
# 1     B       12       87        56       65
# 2     C       11       66        89       63
# 3     D       10       56        88       66
# 4     E       10       89        90       56
# 5     F        9       88        85       89
# 6     G       12       90        83       88
# 7     H       11       79        88       90

# %%
df=pd.read_csv(r'C:\Users\Venugopal\OneDrive\Desktop\Batch_423\EDA\data\std_data1.csv',skiprows=[3,5,8])
df
# Out:
#   SNAME  SCLASS   ENGLISH  COMPUTER  SCIENCE
# 0     A       10       67        66       66
# 1     B       12       87        56       65
# 2     D       10       56        88       66
# 3     F        9       88        85       89
# 4     G       12       90        83       88

# %%
df=pd.read_csv(r'C:\Users\Venugopal\OneDrive\Desktop\Batch_423\EDA\data\std_data1.csv',skiprows=[i for i in range(4,8) ])

# %%
df
# Out:
#   SNAME  SCLASS   ENGLISH  COMPUTER  SCIENCE
# 0     A       10       67        66       66
# 1     B       12       87        56       65
# 2     C       11       66        89       63
# 3     H       11       79        88       90

# %%
df
# Out:
#   SNAME  SCLASS   ENGLISH  COMPUTER  SCIENCE
# 0     A       10       67        66       66
# 1     B       12       87        56       65
# 2     C       11       66        89       63
# 3     D       10       56        88       66
# 4     E       10       89        90       56
# 5     F        9       88        85       89
# 6     G       12       90        83       88
# 7     H       11       79        88       90

# %%
df.iloc[0:3]
# Out:
#   SNAME  SCLASS   ENGLISH  COMPUTER  SCIENCE
# 0     A       10       67        66       66
# 1     B       12       87        56       65
# 2     C       11       66        89       63

# %%
df.iloc[:,0:3]
# Out:
#   SNAME  SCLASS   ENGLISH
# 0     A       10       67
# 1     B       12       87
# 2     C       11       66
# 3     D       10       56
# 4     E       10       89
# 5     F        9       88
# 6     G       12       90
# 7     H       11       79

# %%
df.iloc[4:,3:]
# Out:
#    COMPUTER  SCIENCE
# 4        90       56
# 5        85       89
# 6        83       88
# 7        88       90

# %%
df.loc[4:,'ENGLISH':'SCIENCE']
# Out:
#    ENGLISH  COMPUTER  SCIENCE
# 4       89        90       56
# 5       88        85       89
# 6       90        83       88
# 7       79        88       90

# %%
df
# Out:
#   SNAME  SCLASS   ENGLISH  COMPUTER  SCIENCE
# 0     A       10       67        66       66
# 1     B       12       87        56       65
# 2     C       11       66        89       63
# 3     D       10       56        88       66
# 4     E       10       89        90       56
# 5     F        9       88        85       89
# 6     G       12       90        83       88
# 7     H       11       79        88       90

# %%
df.loc[:,['SNAME','COMPUTER','SCIENCE']]
# Out:
#   SNAME  COMPUTER  SCIENCE
# 0     A        66       66
# 1     B        56       65
# 2     C        89       63
# 3     D        88       66
# 4     E        90       56
# 5     F        85       89
# 6     G        83       88
# 7     H        88       90

# %%
df.iloc[:,[0,3,4]]
# Out:
#   SNAME  COMPUTER  SCIENCE
# 0     A        66       66
# 1     B        56       65
# 2     C        89       63
# 3     D        88       66
# 4     E        90       56
# 5     F        85       89
# 6     G        83       88
# 7     H        88       90

# %%
df.head(3)
# Out:
#   SNAME  SCLASS   ENGLISH  COMPUTER  SCIENCE
# 0     A       10       67        66       66
# 1     B       12       87        56       65
# 2     C       11       66        89       63

# %%
df.tail(3)
# Out:
#   SNAME  SCLASS   ENGLISH  COMPUTER  SCIENCE
# 5     F        9       88        85       89
# 6     G       12       90        83       88
# 7     H       11       79        88       90

# %%
df.head()
# Out:
#   SNAME  SCLASS   ENGLISH  COMPUTER  SCIENCE
# 0     A       10       67        66       66
# 1     B       12       87        56       65
# 2     C       11       66        89       63
# 3     D       10       56        88       66
# 4     E       10       89        90       56

# %%
df.tail()
# Out:
#   SNAME  SCLASS   ENGLISH  COMPUTER  SCIENCE
# 3     D       10       56        88       66
# 4     E       10       89        90       56
# 5     F        9       88        85       89
# 6     G       12       90        83       88
# 7     H       11       79        88       90

# %%
df.columns
# Out:
# Index(['SNAME', 'SCLASS ', 'ENGLISH', 'COMPUTER', 'SCIENCE'], dtype='object')

# %%
df
# Out:
#   SNAME  SCLASS   ENGLISH  COMPUTER  SCIENCE
# 0     A       10       67        66       66
# 1     B       12       87        56       65
# 2     C       11       66        89       63
# 3     D       10       56        88       66
# 4     E       10       89        90       56
# 5     F        9       88        85       89
# 6     G       12       90        83       88
# 7     H       11       79        88       90

# %%
df.to_excel(r'C:\Users\Venugopal\OneDrive\Desktop\Batch_423\EDA\data\test_excel.xlsx',index=False)

# %%
df.to_csv(r'C:\Users\Venugopal\OneDrive\Desktop\Batch_423\EDA\data\test_csv.csv',index=False)
